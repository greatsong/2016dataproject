# %%
import csv
data = csv.reader(open('201605subway.csv','r'),delimiter=",")

i = int(input('몇시가 궁금하신가요?'))-4
max_person = 0
max_station = ''
for row in data : 
    if(int(max_person) < int(row[2+(i*2)])):
        max_person = row[2+(i*2)]
        max_station = row[1]+'('+ row[0]+')'
print(max_station, max_person)

# %%
import csv
data = csv.reader(open('201605subway.csv','r'), delimiter=",")

max_person1 = [0] * 24
max_station1 = [''] * 24

max_person2 = [0] * 24
max_station2 = [''] * 24
for row in data :
    for i in range(24):
        if int(max_person1[i]) < int(row[2+(i*2)]) :
            max_person1[i] = row[2+(i*2)]
            max_station1[i] = row[1] + '/' + str(i+4) #+'('+ row[0]+')'
        if int(max_person2[i]) < int(row[3 + (i * 2)]):
            max_person2[i] = row[3 + (i * 2)]
            max_station2[i] = row[1] + '/' + str(i + 4)  # +'('+ row[0]+')'

for i in range(24):
    print(i+4,'시(승차): ', max_station1[i],'/',max_person1[i])
    print(i + 4,'시(하차): ', max_station2[i], '/', max_person2[i])

import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np
plt.rc('font',family='Malgun Gothic')
cnt = np.arange(24)
plt.subplot(121)
plt.title('2016년 5월 서울시 지하철 시간대별 최다 승차역')
plt.plot(cnt, max_person1,'r')
plt.xticks(cnt, max_station1,rotation='vertical')
plt.ylim(ymax=450000)
plt.subplot(122)
plt.title('2016년 5월 서울시 지하철 시간대별 최다 하차역')
plt.plot(cnt, max_person2,'b')
plt.xticks(cnt, max_station2,rotation='vertical')
plt.ylim(ymax=450000)
plt.show()
# Out:
# 4 시(승차):  구로/4 / 9184
# 4 시(하차):  영등포/4 / 120
# 5 시(승차):  홍대입구/5 / 58213
# 5 시(하차):  강남/5 / 13411
# 6 시(승차):  신림/6 / 99232
# 6 시(하차):  잠실/6 / 83303
# 7 시(승차):  신림/7 / 276737
# 7 시(하차):  강남/7 / 183217
# 8 시(승차):  신림/8 / 364941
# 8 시(하차):  가산디지털단지/8 / 409345
# 9 시(승차):  신림/9 / 214574
# 9 시(하차):  강남/9 / 325053
# 10 시(승차):  신림/10 / 122839
# 10 시(하차):  강남/10 / 174055
# 11 시(승차):  신림/11 / 106601
# 11 시(하차):  강남/11 / 144794
# 12 시(승차):  서울역/12 / 115427
# 12 시(하차):  강남/12 / 142930
# 13 시(승차):  강남/13 / 147726
# 13 시(하차):  강남/13 / 173350
# 14 시(승차):  강남/14 / 147092
# 14 시(하차):  홍대입구/14 / 162179
# 15 시(승차):  강남/15 / 170230
# 15 시(하차):  홍대입구/15 / 163573
# 16 시(승차):  강남/16 / 190116
# 16 시(하차):  홍대입구/16 / 176494
# 17 시(승차):  강남/17 / 233593
# 17 시(하차):  홍대입구/17 / 206261
# 18 시(승차):  강남/18 / 350196
# 18 시(하차):  홍대입구/18 / 264192
# 19 시(승차):  강남/19 / 266168
# 19 시(하차):  신림/19 / 280085
# 20 시(승차):  강남/20 / 213768
# 20 시(하차):  신림/20 / 193155
# 21 시(승차):  강남/21 / 264570
# 21 시(하차):  신림/21 / 182679
# 22 시(승차):  강남/22 / 286095
# 22 시(하차):  신림/22 / 192206
# 23 시(승차):  홍대입구/23 / 148474
# 23 시(하차):  신림/23 / 132949
# 24 시(승차):  강남/24 / 22157
# 24 시(하차):  신림/24 / 43783
# 25 시(승차):  신도림/25 / 17
# 25 시(하차):  서울대입구/25 / 5507
# 26 시(승차):  을지로입구/26 / 4
# 26 시(하차):  을지로입구/26 / 6
# 27 시(승차):  을지로입구/27 / 7
# 27 시(하차):  한성대입구/27 / 7

# %%
import csv
data = csv.reader(open('201605subway.csv','r'),delimiter=",")

인원 = []
역이름 = input('무슨 역인가요?')
호선 = input('몇 호선인가요?')

for row in data :
    if(row[1] == 역이름 and row[0] == 호선):
        print(row[1])
        인원 = row[2:]
    
승차 = 인원[::2]
하차 = 인원[1::2]

print(승차)
print(하차)

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')

labels = []
x = []
for i in range(4,28):
    labels.append(str(i)+'시')
    x.append(i)
    
plt.xticks(x, labels,rotation='vertical')
plt.plot(x,승차,'r', label='승차 인원')
plt.plot(x,하차,'b', label='하차 인원')
plt.ylim(ymax=420000)
plt.title(역이름+'('+호선+')')
plt.legend()
plt.show()
# Out:
# 무슨 역인가요?신도림
# 몇 호선인가요?2호선
# 신도림
# ['2970', '46168', '67342', '175910', '177418', '117820', '84973', '81372', '90583', '97854', '95403', '98514', '103354', '122960', '164920', '120141', '98809', '103592', '88973', '40641', '5406', '17', '1', '0']
# ['20', '7075', '29124', '58160', '145081', '96198', '84395', '78475', '91024', '96197', '92915', '97956', '107435', '134087', '197401', '196138', '117716', '106864', '113415', '87596', '40015', '4311', '1', '0']

# %%
import csv
data = csv.reader(open('201605subway.csv','r'),delimiter=",")

인원1 = []
인원2 = []
역이름1 = input('첫 번째 역 이름을 입력하세요 : ')
호선1 = input('첫 번째 역은 몇 호선인가요? : ')
역이름2 = input('두 번째 역 이름을 입력하세요 : ')
호선2 = input('첫 번째 역은 몇 호선인가요? : ')

for row in data :
    if(row[1] == 역이름1 and row[0] == 호선1): 
        인원1 = row[2:]
    if(row[1] == 역이름2 and row[0] == 호선2):
        인원2 = row[2:]
    
승차1 = 인원1[::2]
하차1 = 인원1[1::2]

승차2 = 인원2[::2]
하차2 = 인원2[1::2]

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')

labels = []
x = []
for i in range(4,28):
    labels.append(str(i)+'시')
    x.append(i)
    
plt.xticks(x, labels,rotation='vertical')
plt.plot(x,승차1,'r', label=역이름1+'역 승차')
plt.plot(x,승차2,'b', label=역이름2+'역 승차')
plt.ylim(ymax=420000)
#plt.title(역이름1+'역 승차 인원 vs '+역이름2+'역 승차 인원   # 2016년 5월 티머니카드 제공 데이터')
#plt.legend()
#plt.show()

plt.xticks(x, labels,rotation='vertical')
plt.plot(x,하차1,'r--', label=역이름1+'역 하차')
plt.plot(x,하차2,'b--', label=역이름2+'역 하차')
plt.ylim(ymax=420000)
plt.title(역이름1+'역 승하차 인원 vs '+역이름2+'역 승하차 인원   # 2016년 5월 티머니카드 제공 데이터')
plt.legend()
plt.show()
# Out:
# 첫 번째 역 이름을 입력하세요 : 강남
# 첫 번째 역은 몇 호선인가요? : 2호선
# 두 번째 역 이름을 입력하세요 : 신림
# 첫 번째 역은 몇 호선인가요? : 2호선
